# %% [markdown]
# ## Assignment 1:
#
# - Using Numpy to implement the soft-margin SVM model.
# - Train this model using SGD method on the [Chest X-Ray Images (Pneumonia)](https://www.kaggle.com/datasets/paultimothymooney/chest-xray-pneumonia). Resize the images to $128 \times 128$.
# - Evaluate this model using Precision, Recall, and F1 metrics.

# %%
from google.colab import drive
drive.mount('/content/drive')

import sys
sys.path.append('/content/drive/MyDrive/[DS102.Q21]/Lab3/Lab3')
data_path = "/content/drive/MyDrive/[DS102.Q21]/Lab3/Lab3/data"

from src.models.assignment1_train import train_model
from src.evaluation.metrics_assignment1 import (
    confusion_matrix,
    classification_report
)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
model_svm, X_test_svm, y_test_svm = train_model(data_path)
y_pred_svm = model_svm.predict(X_test_svm)
print("\n------------ Assignment 1 ------------")
print("📊 MODEL EVALUATION")
print("Confusion Matrix:")
print(confusion_matrix(y_test_svm, y_pred_svm))
print("\nClassification Report:")
print(classification_report(y_test_svm, y_pred_svm))
# Out:
# Loaded: 2847 ảnh
# Skipped: 2 / 2849
#
# ------------ Assignment 1 ------------
# 📊 MODEL EVALUATION
# Confusion Matrix:
# [[ 0 50]
#  [ 0 50]]
#
# Classification Report:
#
# Accuracy : 0.5000
# Precision: 0.5000
# Recall   : 1.0000
# F1-score : 0.6667

# %% [markdown]
# ## Assigment 2:
# - Implement SVM method using a machine learning library (such as sklearn or sktorch).
# - Train this model on the [Chest X-Ray Images (Pneumonia)](https://www.kaggle.com/datasets/paultimothymooney/chest-xray-pneumonia). Resize the images to $128 \times 128$.
# - Evaluate this model using Precision, Recall, and F1 metrics.
# - Compare the results of SVM using library to those of implemented SVM.

# %%
from src.models.assignment2_train import train_sklearn_svm
from src.evaluation.metrics_assignment2 import evaluate

# %%
model_sklearn_svm, X_test_sklearn_svm, y_test_sklearn_svm = train_sklearn_svm(data_path)
y_pred_sklearn_svm = model_sklearn_svm.predict(X_test_sklearn_svm)
evaluate(y_test_sklearn_svm, y_pred_sklearn_svm)
# Out:
# Loaded: 2847 ảnh
# Skipped: 2 / 2849
# ------------ Assignment 2 ------------
# 📊 MODEL EVALUATION
#
# Confusion Matrix:
# [[ 0 50]
#  [ 0 50]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00        50
#            1       0.50      1.00      0.67        50
#
#     accuracy                           0.50       100
#    macro avg       0.25      0.50      0.33       100
# weighted avg       0.25      0.50      0.33       100
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...
